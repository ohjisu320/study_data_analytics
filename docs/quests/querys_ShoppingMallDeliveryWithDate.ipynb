# %% [markdown]
# <a href="https://colab.research.google.com/github/ohjisu320/study_data_analytics/blob/main/docs/quests/querys_ShoppingMallDeliveryWithDate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df_shop = pd.read_csv('ShoppingMallDeliveryWithDate.csv')

# %%
df_shop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17884 entries, 0 to 17883
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   결제수단    17884 non-null  object
#  1   배송번호    17884 non-null  object
#  2   배송시작일   17884 non-null  object
#  3   배송완료일   17883 non-null  object
#  4   상품구매금액  17883 non-null  float64
#  5   상품번호    17883 non-null  float64
#  6   수량      17883 non-null  float64
#  7   주문경로    17883 non-null  object
#  8   주문일     17883 non-null  float64
# dtypes: float64(4), object(5)
# memory usage: 1.2+ MB

# %% [markdown]
# ### 1. 상품구매금액이 80,000원 이상인 주문들을 찾으세요.

# %%
df_shop['상품구매금액']
# Out:
# 0         71450.0
# 1        141240.0
# 2         13910.0
# 3         81600.0
# 4         94710.0
#            ...
# 17879    118850.0
# 17880         0.0
# 17881     96850.0
# 17882     53900.0
# 17883         NaN
# Name: 상품구매금액, Length: 17884, dtype: float64

# %%
condition = "상품구매금액 > 80000"
df_shop[['상품구매금액']].query(condition)
# Out:
#          상품구매금액
# 1      141240.0
# 3       81600.0
# 4       94710.0
# 6       82170.0
# 8      300960.0
# ...         ...
# 17874  104000.0
# 17876   96850.0
# 17878  127600.0
# 17879  118850.0
# 17881   96850.0
#
# [6180 rows x 1 columns]

# %% [markdown]
# ### 2. 모바일웹을 통해 주문된 상품 중, 상품구매금액이 평균 이상인 주문들을 찾으세요.

# %%
df_shop[['주문경로']]
# Out:
#          주문경로
# 0       PC쇼핑몰
# 1        모바일웹
# 2        모바일웹
# 3        모바일웹
# 4        모바일웹
# ...       ...
# 17879   PC쇼핑몰
# 17880   PC쇼핑몰
# 17881  네이버 페이
# 17882   PC쇼핑몰
# 17883     NaN
#
# [17884 rows x 1 columns]

# %%
df_shop['상품구매금액'].mean().astype(int)
# Out:
# 80355

# %%
condition_mobile = "주문경로 == '모바일웹'"
df_shop_mobile = df_shop[['주문경로', '상품구매금액']].query(condition_mobile)
df_shop_mobile
# Out:
#        주문경로    상품구매금액
# 1      모바일웹  141240.0
# 2      모바일웹   13910.0
# 3      모바일웹   81600.0
# 4      모바일웹   94710.0
# 5      모바일웹   75240.0
# ...     ...       ...
# 17862  모바일웹   84700.0
# 17863  모바일웹   96850.0
# 17864  모바일웹       0.0
# 17876  모바일웹   96850.0
# 17877  모바일웹       0.0
#
# [7803 rows x 2 columns]

# %%
mean = df_shop_mobile['상품구매금액'].mean().astype(int)
mean
# Out:
# 80450

# %%
condition_over = f"상품구매금액 > {mean}"
df_shop_mobile = df_shop_mobile.query(condition_over)
df_shop_mobile
# Out:
#        주문경로    상품구매금액
# 1      모바일웹  141240.0
# 3      모바일웹   81600.0
# 4      모바일웹   94710.0
# 21     모바일웹  115170.0
# 25     모바일웹  190420.0
# ...     ...       ...
# 17858  모바일웹   82500.0
# 17860  모바일웹   96850.0
# 17862  모바일웹   84700.0
# 17863  모바일웹   96850.0
# 17876  모바일웹   96850.0
#
# [2661 rows x 2 columns]

# %% [markdown]
# ### 3. 2019년 1월 7일 이전에 배송이 시작된 주문들을 찾으세요.

# %%
df_shop[['배송시작일']][:2]
# Out:
#                 배송시작일
# 0  2019-01-07 오전 8:56
# 1  2019-01-03 오전 9:30

# %%
def convert_time(x):
    date, ampm, time = x.split()
    if ampm == "오후" and time != "12:00":
        hour, minute = map(int, time.split(":"))
        time = f"{hour+12 if hour != 12 else hour}:{minute}"
    return pd.to_datetime(f"{date} {time}", format="%Y-%m-%d %H:%M")
pass
df_shop["배송시작일"] = df_shop["배송시작일"].apply(convert_time)

# %%
condition = "배송시작일 < 20190107"
df_shop.query(condition).sort_values(by='배송시작일')
# Out:
#         결제수단                   배송번호               배송시작일                배송완료일  \
# 17549  무통장입금  D-20171227-0000094-00 2018-01-02 17:59:00   2018-01-06 오전 5:33
# 17571     카드  D-20180102-0000105-01 2018-01-02 17:59:00   2018-01-06 오전 5:33
# 17570     카드  D-20180102-0000105-00 2018-01-02 17:59:00   2018-01-06 오전 5:33
# 17569     카드  D-20180102-0000073-00 2018-01-02 17:59:00   2018-01-06 오전 5:33
# 17565     카드  D-20180102-0000045-00 2018-01-02 17:59:00   2018-01-06 오전 5:33
# ...      ...                    ...                 ...                  ...
# 283    무통장입금  D-20190103-0000514-01 2019-01-03 18:20:00   2019-01-12 오후 3:16
# 194       카드  D-20190102-0000938-02 2019-01-03 18:20:00   2019-01-13 오전 4:38
# 195       카드  D-20190102-0000938-03 2019-01-03 18:20:00   2019-01-13 오전 4:38
# 223       카드  D-20190103-0000012-01 2019-01-03 18:20:00  2019-01-12 오전 11:23
# 134       카드  D-20190102-0000498-01 2019-01-03 18:20:00   2019-01-28 오후 4:15
#
#          상품구매금액    상품번호   수량    주문경로         주문일
# 17549  167420.0    46.0  2.0   PC쇼핑몰  20171227.0
# 17571  279000.0    88.0  3.0   PC쇼핑몰  20180102.0
# 17570   96850.0    90.0  1.0   PC쇼핑몰  20180102.0
# 17569       0.0   360.0  1.0   PC쇼핑몰  20180102.0
# 17565       0.0   352.0  1.0    모바일웹  20180102.0
# ...         ...     ...  ...     ...         ...
# 283     70620.0    42.0  1.0  네이버 페이  20190103.0
# 194     77220.0   379.0  1.0  네이버 페이  20190102.0
# 195     72270.0   378.0  1.0  네이버 페이  20190102.0
# 223     56760.0   172.0  1.0  네이버 페이  20190103.0
# 134    129360.0  1217.0  1.0  네이버 페이  20190102.0
#
# [640 rows x 9 columns]

# %% [markdown]
# ### 4. 배송 시작일과 배송 완료일이 3일 이상 차이 나는 주문들을 찾으세요.

# %%
 df_shop["배송완료일"]
# Out:
# 0        2019-01-11 오전 5:32
# 1        2019-01-07 오전 5:32
# 2        2019-01-07 오전 5:32
# 3        2019-01-07 오전 5:32
# 4        2019-01-11 오전 5:32
#                 ...
# 17879    2018-01-19 오전 5:38
# 17880    2018-01-19 오전 5:38
# 17881    2018-01-19 오전 8:20
# 17882    2018-01-19 오전 5:38
# 17883                   NaN
# Name: 배송완료일, Length: 17884, dtype: object

# %%
def convert_time_finish(x):
  try :
    date, ampm, time = x.split()
    if ampm == "오후" and time != "12:00":
        hour, minute = map(int, time.split(":"))
        time = f"{hour+12 if hour != 12 else hour}:{minute}"
    return pd.to_datetime(f"{date} {time}", format="%Y-%m-%d %H:%M")
  except :
    return 'nan'
pass
df_shop["배송완료일"] = df_shop["배송완료일"].apply(convert_time_finish)
# Out:
# <ipython-input-48-9047824dbdca>:11: FutureWarning: Inferring datetime64[ns] from data containing strings is deprecated and will be removed in a future version. To retain the old behavior explicitly pass Series(data, dtype=datetime64[ns])
#   df_shop["배송완료일"] = df_shop["배송완료일"].apply(convert_time_finish)

# %%
df_shop["배송기간"] = df_shop["배송완료일"]-df_shop["배송시작일"]
df_shop["배송기간"] = df_shop["배송기간"].dt.days

# %%
condition = '배송기간 >= 3 '
df_shop.query(condition)
# Out:
#         결제수단                   배송번호               배송시작일               배송완료일  \
# 0      무통장입금  D-20181227-0000648-00 2019-01-07 08:56:00 2019-01-11 05:32:00
# 1      무통장입금  D-20181229-0000119-00 2019-01-03 09:30:00 2019-01-07 05:32:00
# 2      무통장입금  D-20181230-0000100-00 2019-01-03 09:30:00 2019-01-07 05:32:00
# 3      무통장입금  D-20181231-0000087-00 2019-01-03 09:30:00 2019-01-07 05:32:00
# 4      무통장입금  D-20181231-0000108-00 2019-01-07 08:56:00 2019-01-11 05:32:00
# ...      ...                    ...                 ...                 ...
# 17878  무통장입금  D-20180115-0000026-00 2018-01-15 17:45:00 2018-01-19 05:38:00
# 17879  무통장입금  D-20180115-0000026-01 2018-01-15 17:45:00 2018-01-19 05:38:00
# 17880  무통장입금  D-20180115-0000026-00 2018-01-15 17:45:00 2018-01-19 05:38:00
# 17881     카드  D-20180115-0000050-01 2018-01-15 17:46:00 2018-01-19 08:20:00
# 17882  무통장입금  D-20180115-0000067-00 2018-01-15 17:45:00 2018-01-19 05:38:00
#
#          상품구매금액    상품번호   수량    주문경로         주문일  배송기간
# 0       71450.0  1077.0  1.0   PC쇼핑몰  20181227.0   3.0
# 1      141240.0    42.0  2.0    모바일웹  20181229.0   3.0
# 2       13910.0  1271.0  1.0    모바일웹  20181230.0   3.0
# 3       81600.0  1085.0  1.0    모바일웹  20181231.0   3.0
# 4       94710.0  1106.0  1.0    모바일웹  20181231.0   3.0
# ...         ...     ...  ...     ...         ...   ...
# 17878  127600.0    41.0  1.0   PC쇼핑몰  20180115.0   3.0
# 17879  118850.0    94.0  1.0   PC쇼핑몰  20180115.0   3.0
# 17880       0.0   360.0  1.0   PC쇼핑몰  20180115.0   3.0
# 17881   96850.0    90.0  1.0  네이버 페이  20180115.0   3.0
# 17882   53900.0   455.0  1.0   PC쇼핑몰  20180115.0   3.0
#
# [17728 rows x 10 columns]

# %% [markdown]
# ### 5. 무통장입금을 결제수단으로 사용한 주문 중, 상품번호가 1000번 이상인 주문들을 찾으세요.

# %%
condition = '결제수단 == "무통장입금"'
df_shop_direct = df_shop.query(condition)
condition_over_1000 = '상품번호 >= 1000'
df_shop_direct.query(condition_over_1000).sort_values(by='상품번호')
# Out:
#         결제수단                   배송번호               배송시작일               배송완료일  \
# 1135   무통장입금  D-20190111-0000391-00 2019-01-16 09:01:00 2019-01-20 05:32:00
# 4683   무통장입금  D-20190214-0000753-01 2019-02-18 18:15:00 2019-02-22 05:32:00
# 2329   무통장입금  D-20190123-0000371-00 2019-01-24 18:32:00 2019-01-28 05:32:00
# 13173  무통장입금  D-20190425-0000081-00 2019-04-29 09:01:00 2019-05-03 05:32:00
# 12678  무통장입금  D-20190422-0000147-00 2019-04-23 18:53:00 2019-04-27 05:32:00
# ...      ...                    ...                 ...                 ...
# 12878  무통장입금  D-20190423-0000328-00 2019-04-30 18:33:00 2019-05-04 05:32:00
# 17546  무통장입금  D-20190602-0000017-04 2019-06-10 08:45:00 2019-06-14 05:32:00
# 15060  무통장입금  D-20190509-0000898-00 2019-05-10 19:05:00 2019-05-14 05:32:00
# 15664  무통장입금  D-20190515-0000778-00 2019-05-17 18:33:00 2019-05-21 05:32:00
# 16871  무통장입금  D-20190527-0000135-00 2019-05-29 11:31:00 2019-06-02 05:32:00
#
#          상품구매금액    상품번호   수량   주문경로         주문일  배송기간
# 1135    24630.0  1019.0  1.0  PC쇼핑몰  20190111.0   3.0
# 4683   173100.0  1024.0  1.0  PC쇼핑몰  20190214.0   3.0
# 2329   199100.0  1024.0  1.0  PC쇼핑몰  20190123.0   3.0
# 13173  173100.0  1024.0  1.0  PC쇼핑몰  20190425.0   3.0
# 12678  173100.0  1024.0  1.0  PC쇼핑몰  20190422.0   3.0
# ...         ...     ...  ...    ...         ...   ...
# 12878   56130.0  1608.0  1.0  PC쇼핑몰  20190423.0   3.0
# 17546   90000.0  1625.0  2.0   모바일웹  20190602.0   3.0
# 15060   22500.0  1632.0  1.0   모바일웹  20190509.0   3.0
# 15664    6430.0  1633.0  1.0  PC쇼핑몰  20190515.0   3.0
# 16871   12740.0  1680.0  1.0  PC쇼핑몰  20190527.0   3.0
#
# [5234 rows x 10 columns]

# %% [markdown]
# ### 6. 상품번호가 50번 이하이거나 1000번 이상인 주문들을 찾으세요.

# %%
condition_under_50 = '상품번호 <= 50'
condition_over_1000 = '상품번호 >=1000'
conditions = f'{condition_under_50} or {condition_over_1000}'
df_shop.query(conditions).sort_values(by='상품번호')
# Out:
#             결제수단                   배송번호               배송시작일  \
# 12800  적립금,무통장입금  D-20190422-0000971-00 2019-04-23 18:53:00
# 8770       무통장입금  D-20190319-0000686-01 2019-03-20 08:45:00
# 12897         카드  D-20190423-0000471-00 2019-04-23 18:53:00
# 12895         카드  D-20190423-0000449-00 2019-04-23 18:53:00
# 12865      무통장입금  D-20190423-0000243-00 2019-04-23 18:53:00
# ...          ...                    ...                 ...
# 15664      무통장입금  D-20190515-0000778-00 2019-05-17 18:33:00
# 16201         카드  D-20190520-0000631-00 2019-05-22 09:11:00
# 16871      무통장입금  D-20190527-0000135-00 2019-05-29 11:31:00
# 17053     적립금,카드  D-20190528-0000085-00 2019-05-29 11:31:00
# 17250     적립금,카드  D-20190529-0000343-00 2019-05-30 10:20:00
#
#                     배송완료일   상품구매금액    상품번호   수량   주문경로         주문일  배송기간
# 12800 2019-04-27 05:32:00  55870.0    38.0  1.0   모바일웹  20190422.0   3.0
# 8770  2019-03-24 05:32:00  55870.0    38.0  1.0  PC쇼핑몰  20190319.0   3.0
# 12897 2019-04-27 05:32:00  55870.0    38.0  1.0  PC쇼핑몰  20190423.0   3.0
# 12895 2019-04-27 05:32:00  55870.0    38.0  1.0  PC쇼핑몰  20190423.0   3.0
# 12865 2019-04-27 05:32:00  55870.0    38.0  1.0  PC쇼핑몰  20190423.0   3.0
# ...                   ...      ...     ...  ...    ...         ...   ...
# 15664 2019-05-21 05:32:00   6430.0  1633.0  1.0  PC쇼핑몰  20190515.0   3.0
# 16201 2019-05-26 05:32:00   6500.0  1679.0  1.0   모바일웹  20190520.0   3.0
# 16871 2019-06-02 05:32:00  12740.0  1680.0  1.0  PC쇼핑몰  20190527.0   3.0
# 17053 2019-06-02 05:32:00  49180.0  1681.0  1.0  PC쇼핑몰  20190528.0   3.0
# 17250 2019-06-03 05:32:00  55000.0  1681.0  1.0   모바일웹  20190529.0   3.0
#
# [11225 rows x 10 columns]

# %% [markdown]
# ### 7. 주문일이 20181231인 주문 중, 수량이 1개 이상인 주문들을 찾으세요.

# %%
df_shop['수량'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 17884 entries, 0 to 17883
# Series name: 수량
# Non-Null Count  Dtype
# --------------  -----
# 17883 non-null  float64
# dtypes: float64(1)
# memory usage: 139.8 KB

# %%
condition_orderdate = '주문일 == 20181231'
condition_sku = '수량 >= 1'
conditions = f'{condition_orderdate} and {condition_sku}'
df_shop.query(conditions)
# Out:
#          결제수단                   배송번호               배송시작일               배송완료일  \
# 3       무통장입금  D-20181231-0000087-00 2019-01-03 09:30:00 2019-01-07 05:32:00
# 4       무통장입금  D-20181231-0000108-00 2019-01-07 08:56:00 2019-01-11 05:32:00
# 5       무통장입금  D-20181231-0000108-01 2019-01-07 08:56:00 2019-01-11 05:32:00
# 6       무통장입금  D-20181231-0000184-00 2019-01-03 09:30:00 2019-01-07 05:32:00
# 7       무통장입금  D-20181231-0000184-01 2019-01-03 09:30:00 2019-01-07 05:32:00
# 8       무통장입금  D-20181231-0000184-02 2019-01-03 09:30:00 2019-01-07 05:32:00
# 9       무통장입금  D-20181231-0000184-03 2019-01-03 09:30:00 2019-01-07 05:32:00
# 10      무통장입금  D-20181231-0000205-00 2019-01-03 09:30:00 2019-01-07 05:32:00
# 11      무통장입금  D-20181231-0000205-01 2019-01-03 09:30:00 2019-01-07 05:32:00
# 12      무통장입금  D-20181231-0000205-02 2019-01-03 09:30:00 2019-01-07 05:32:00
# 13      무통장입금  D-20181231-0000205-03 2019-01-03 09:30:00 2019-01-07 05:32:00
# 14      무통장입금  D-20181231-0000205-04 2019-01-03 09:30:00 2019-01-07 05:32:00
# 15      무통장입금  D-20181231-0000205-05 2019-01-03 09:30:00 2019-01-07 05:32:00
# 16      무통장입금  D-20181231-0000211-00 2019-01-03 09:30:00 2019-01-07 05:32:00
# 17      무통장입금  D-20181231-0000211-01 2019-01-03 09:30:00 2019-01-07 05:32:00
# 18      무통장입금  D-20181231-0000211-02 2019-01-03 09:30:00 2019-01-07 05:32:00
# 19      무통장입금  D-20181231-0000211-03 2019-01-03 09:30:00 2019-01-07 05:32:00
# 20      무통장입금  D-20181231-0000373-00 2019-01-03 09:30:00 2019-01-07 05:32:00
# 21  적립금,무통장입금  D-20181231-0000512-00 2019-01-03 09:30:00 2019-01-07 05:32:00
# 22      무통장입금  D-20181231-0000635-00 2019-01-03 09:30:00 2019-01-07 05:32:00
# 23      무통장입금  D-20181231-0000650-00 2019-01-03 09:30:00 2019-01-07 05:32:00
# 24      무통장입금  D-20181231-0000664-00 2019-01-03 18:19:00 2019-01-07 05:32:00
# 25      무통장입금  D-20181231-0000727-00 2019-01-03 18:19:00 2019-01-07 05:32:00
# 26      무통장입금  D-20181231-0000745-00 2019-01-03 09:30:00 2019-01-07 05:32:00
# 27  적립금,무통장입금  D-20181231-0000766-00 2019-01-03 09:30:00 2019-01-07 05:32:00
# 28  적립금,무통장입금  D-20181231-0000766-01 2019-01-03 09:30:00 2019-01-07 05:32:00
# 29  적립금,무통장입금  D-20181231-0000766-02 2019-01-03 09:30:00 2019-01-07 05:32:00
# 30      무통장입금  D-20181231-0000777-00 2019-01-03 09:30:00 2019-01-07 05:32:00
# 31      무통장입금  D-20181231-0000777-01 2019-01-03 09:30:00 2019-01-07 05:32:00
# 32      무통장입금  D-20181231-0000891-00 2019-01-03 09:30:00 2019-01-07 05:32:00
#
#       상품구매금액    상품번호   수량   주문경로         주문일  배송기간
# 3    81600.0  1085.0  1.0   모바일웹  20181231.0   3.0
# 4    94710.0  1106.0  1.0   모바일웹  20181231.0   3.0
# 5    75240.0  1374.0  1.0   모바일웹  20181231.0   3.0
# 6    82170.0  1071.0  1.0  PC쇼핑몰  20181231.0   3.0
# 7    63470.0  1373.0  1.0  PC쇼핑몰  20181231.0   3.0
# 8   300960.0  1374.0  4.0  PC쇼핑몰  20181231.0   3.0
# 9   121110.0  1037.0  1.0  PC쇼핑몰  20181231.0   3.0
# 10   94710.0  1058.0  1.0  PC쇼핑몰  20181231.0   3.0
# 11  107910.0  1059.0  1.0  PC쇼핑몰  20181231.0   3.0
# 12   82170.0  1071.0  1.0  PC쇼핑몰  20181231.0   3.0
# 13   63470.0  1373.0  1.0  PC쇼핑몰  20181231.0   3.0
# 14   75240.0  1374.0  1.0  PC쇼핑몰  20181231.0   3.0
# 15  121110.0  1037.0  1.0  PC쇼핑몰  20181231.0   3.0
# 16  126940.0  1373.0  2.0  PC쇼핑몰  20181231.0   3.0
# 17   75240.0  1374.0  1.0  PC쇼핑몰  20181231.0   3.0
# 18  121110.0  1037.0  1.0  PC쇼핑몰  20181231.0   3.0
# 19   75240.0  1374.0  1.0  PC쇼핑몰  20181231.0   3.0
# 20   71450.0  1077.0  1.0  PC쇼핑몰  20181231.0   3.0
# 21  115170.0    68.0  1.0   모바일웹  20181231.0   3.0
# 22   78870.0   603.0  1.0  PC쇼핑몰  20181231.0   3.0
# 23   76400.0   608.0  1.0  PC쇼핑몰  20181231.0   3.0
# 24  116820.0   455.0  2.0  PC쇼핑몰  20181231.0   3.0
# 25  190420.0  1322.0  2.0   모바일웹  20181231.0   3.0
# 26   70620.0  1275.0  1.0  PC쇼핑몰  20181231.0   3.0
# 27  126940.0  1373.0  2.0   모바일웹  20181231.0   3.0
# 28   75240.0  1374.0  1.0   모바일웹  20181231.0   3.0
# 29   41910.0  1205.0  1.0   모바일웹  20181231.0   3.0
# 30   75240.0  1374.0  1.0  PC쇼핑몰  20181231.0   3.0
# 31   63470.0  1373.0  1.0  PC쇼핑몰  20181231.0   3.0
# 32   58410.0   455.0  1.0   모바일웹  20181231.0   3.0

# %% [markdown]
# ### 8. PC쇼핑몰을 통해 주문된 상품 중, 배송번호가 'D-20181231'로 시작하는 주문들을 찾으세요.

# %%
condition_pc = '주문경로 == "PC쇼핑몰"'
df_shop_pc = df_shop.query(condition_pc)
condition_number = df_shop_pc['배송번호'].str.contains('D-20181231')
df_shop_pc.loc[condition_number]
# Out:
#      결제수단                   배송번호               배송시작일               배송완료일  \
# 6   무통장입금  D-20181231-0000184-00 2019-01-03 09:30:00 2019-01-07 05:32:00
# 7   무통장입금  D-20181231-0000184-01 2019-01-03 09:30:00 2019-01-07 05:32:00
# 8   무통장입금  D-20181231-0000184-02 2019-01-03 09:30:00 2019-01-07 05:32:00
# 9   무통장입금  D-20181231-0000184-03 2019-01-03 09:30:00 2019-01-07 05:32:00
# 10  무통장입금  D-20181231-0000205-00 2019-01-03 09:30:00 2019-01-07 05:32:00
# 11  무통장입금  D-20181231-0000205-01 2019-01-03 09:30:00 2019-01-07 05:32:00
# 12  무통장입금  D-20181231-0000205-02 2019-01-03 09:30:00 2019-01-07 05:32:00
# 13  무통장입금  D-20181231-0000205-03 2019-01-03 09:30:00 2019-01-07 05:32:00
# 14  무통장입금  D-20181231-0000205-04 2019-01-03 09:30:00 2019-01-07 05:32:00
# 15  무통장입금  D-20181231-0000205-05 2019-01-03 09:30:00 2019-01-07 05:32:00
# 16  무통장입금  D-20181231-0000211-00 2019-01-03 09:30:00 2019-01-07 05:32:00
# 17  무통장입금  D-20181231-0000211-01 2019-01-03 09:30:00 2019-01-07 05:32:00
# 18  무통장입금  D-20181231-0000211-02 2019-01-03 09:30:00 2019-01-07 05:32:00
# 19  무통장입금  D-20181231-0000211-03 2019-01-03 09:30:00 2019-01-07 05:32:00
# 20  무통장입금  D-20181231-0000373-00 2019-01-03 09:30:00 2019-01-07 05:32:00
# 22  무통장입금  D-20181231-0000635-00 2019-01-03 09:30:00 2019-01-07 05:32:00
# 23  무통장입금  D-20181231-0000650-00 2019-01-03 09:30:00 2019-01-07 05:32:00
# 24  무통장입금  D-20181231-0000664-00 2019-01-03 18:19:00 2019-01-07 05:32:00
# 26  무통장입금  D-20181231-0000745-00 2019-01-03 09:30:00 2019-01-07 05:32:00
# 30  무통장입금  D-20181231-0000777-00 2019-01-03 09:30:00 2019-01-07 05:32:00
# 31  무통장입금  D-20181231-0000777-01 2019-01-03 09:30:00 2019-01-07 05:32:00
#
#       상품구매금액    상품번호   수량   주문경로         주문일  배송기간
# 6    82170.0  1071.0  1.0  PC쇼핑몰  20181231.0   3.0
# 7    63470.0  1373.0  1.0  PC쇼핑몰  20181231.0   3.0
# 8   300960.0  1374.0  4.0  PC쇼핑몰  20181231.0   3.0
# 9   121110.0  1037.0  1.0  PC쇼핑몰  20181231.0   3.0
# 10   94710.0  1058.0  1.0  PC쇼핑몰  20181231.0   3.0
# 11  107910.0  1059.0  1.0  PC쇼핑몰  20181231.0   3.0
# 12   82170.0  1071.0  1.0  PC쇼핑몰  20181231.0   3.0
# 13   63470.0  1373.0  1.0  PC쇼핑몰  20181231.0   3.0
# 14   75240.0  1374.0  1.0  PC쇼핑몰  20181231.0   3.0
# 15  121110.0  1037.0  1.0  PC쇼핑몰  20181231.0   3.0
# 16  126940.0  1373.0  2.0  PC쇼핑몰  20181231.0   3.0
# 17   75240.0  1374.0  1.0  PC쇼핑몰  20181231.0   3.0
# 18  121110.0  1037.0  1.0  PC쇼핑몰  20181231.0   3.0
# 19   75240.0  1374.0  1.0  PC쇼핑몰  20181231.0   3.0
# 20   71450.0  1077.0  1.0  PC쇼핑몰  20181231.0   3.0
# 22   78870.0   603.0  1.0  PC쇼핑몰  20181231.0   3.0
# 23   76400.0   608.0  1.0  PC쇼핑몰  20181231.0   3.0
# 24  116820.0   455.0  2.0  PC쇼핑몰  20181231.0   3.0
# 26   70620.0  1275.0  1.0  PC쇼핑몰  20181231.0   3.0
# 30   75240.0  1374.0  1.0  PC쇼핑몰  20181231.0   3.0
# 31   63470.0  1373.0  1.0  PC쇼핑몰  20181231.0   3.0

# %% [markdown]
# ### 9. 상품구매금액이 70,000원 이상 100,000원 이하인 주문들 중, 수량이 1개인 주문들을 찾으세요.

# %%
df_shop['수량']
# Out:
# 0        1.0
# 1        2.0
# 2        1.0
# 3        1.0
# 4        1.0
#         ...
# 17879    1.0
# 17880    1.0
# 17881    1.0
# 17882    1.0
# 17883    NaN
# Name: 수량, Length: 17884, dtype: float64

# %%
condition_overunder = '70000 <= 상품구매금액 <= 100000'
condition_sku = '수량==1'
conditions = f"{condition_overunder} and {condition_sku}"
df_shop.query(conditions).sort_values(by='상품구매금액')
# Out:
#             결제수단                   배송번호               배송시작일  \
# 12160  적립금,무통장입금  D-20190416-0000362-00 2019-04-16 18:26:00
# 17044       가상계좌  D-20190528-0000021-00 2019-05-29 11:31:00
# 14618      무통장입금  D-20190507-0000593-00 2019-05-08 10:03:00
# 15586         카드  D-20190515-0000121-00 2019-05-16 10:44:00
# 13762      무통장입금  D-20190430-0000334-01 2019-04-30 18:33:00
# ...          ...                    ...                 ...
# 463           카드  D-20190104-0000765-02 2019-01-08 08:44:00
# 461           카드  D-20190104-0000754-02 2019-01-08 08:43:00
# 60           휴대폰  D-20190101-0000153-03 2019-01-03 09:30:00
# 3247          카드  D-20190129-0000775-00 2019-01-29 18:49:00
# 3753          카드  D-20190207-0000984-00 2019-02-08 09:53:00
#
#                     배송완료일   상품구매금액    상품번호   수량    주문경로         주문일  배송기간
# 12160 2019-04-20 05:32:00  70000.0   397.0  1.0    모바일웹  20190416.0   3.0
# 17044 2019-06-02 05:32:00  70000.0   397.0  1.0    모바일웹  20190528.0   3.0
# 14618 2019-05-12 05:32:00  70000.0   397.0  1.0    모바일웹  20190507.0   3.0
# 15586 2019-05-20 05:32:00  70000.0   397.0  1.0   PC쇼핑몰  20190515.0   3.0
# 13762 2019-05-04 05:32:00  70000.0   397.0  1.0   PC쇼핑몰  20190430.0   3.0
# ...                   ...      ...     ...  ...     ...         ...   ...
# 463   2019-01-16 02:13:00  99660.0  1236.0  1.0  네이버 페이  20190104.0   7.0
# 461   2019-01-12 05:32:00  99660.0  1236.0  1.0    모바일웹  20190104.0   3.0
# 60    2019-01-03 23:15:00  99660.0  1235.0  1.0  네이버 페이  20190101.0   0.0
# 3247  2019-02-02 05:32:00  99660.0  1235.0  1.0    모바일웹  20190129.0   3.0
# 3753  2019-02-12 05:32:00  99660.0  1236.0  1.0    모바일웹  20190207.0   3.0
#
# [4751 rows x 10 columns]

# %% [markdown]
# ### 10. 모바일웹을 통한 주문 중, 배송번호가 'D-20181230' 이후로 시작되고 상품구매금액이 50,000원 이상인 주문들을 찾으세요.

# %% [markdown]
# #### 배송번호의 앞이 주문일과 같은걸 이용했을 때

# %%
condition_mobile = '주문경로=="모바일웹"'
condition_over = '50000 <= 상품구매금액'
condition_orderdate = '주문일 >=20181230'
conditions = f"{condition_over} and {condition_orderdate} and {condition_mobile}"
df_shop.query(conditions).sort_values(by='주문일')
# Out:
#                  결제수단                   배송번호               배송시작일  \
# 3               무통장입금  D-20181231-0000087-00 2019-01-03 09:30:00
# 4               무통장입금  D-20181231-0000108-00 2019-01-07 08:56:00
# 5               무통장입금  D-20181231-0000108-01 2019-01-07 08:56:00
# 21          적립금,무통장입금  D-20181231-0000512-00 2019-01-03 09:30:00
# 25              무통장입금  D-20181231-0000727-00 2019-01-03 18:19:00
# ...               ...                    ...                 ...
# 17544           무통장입금  D-20190602-0000017-02 2019-06-10 08:45:00
# 17546           무통장입금  D-20190602-0000017-04 2019-06-10 08:45:00
# 17545    카카오페이(카카오머니)  D-20190604-0000018-00 2019-06-10 08:45:00
# 17547  페이나우(실시간 계좌이체)  D-20190619-0000037-00 2019-06-20 17:32:00
# 17548  페이나우(실시간 계좌이체)  D-20190619-0000053-00 2019-06-20 17:32:00
#
#                     배송완료일    상품구매금액    상품번호   수량  주문경로         주문일  배송기간
# 3     2019-01-07 05:32:00   81600.0  1085.0  1.0  모바일웹  20181231.0   3.0
# 4     2019-01-11 05:32:00   94710.0  1106.0  1.0  모바일웹  20181231.0   3.0
# 5     2019-01-11 05:32:00   75240.0  1374.0  1.0  모바일웹  20181231.0   3.0
# 21    2019-01-07 05:32:00  115170.0    68.0  1.0  모바일웹  20181231.0   3.0
# 25    2019-01-07 05:32:00  190420.0  1322.0  2.0  모바일웹  20181231.0   3.0
# ...                   ...       ...     ...  ...   ...         ...   ...
# 17544 2019-06-14 05:32:00   60900.0  1374.0  1.0  모바일웹  20190602.0   3.0
# 17546 2019-06-14 05:32:00   90000.0  1625.0  2.0  모바일웹  20190602.0   3.0
# 17545 2019-06-14 05:32:00   61900.0   608.0  1.0  모바일웹  20190604.0   3.0
# 17547 2019-06-24 05:32:00   52400.0  1373.0  1.0  모바일웹  20190619.0   3.0
# 17548 2019-06-24 05:32:00   60900.0  1374.0  1.0  모바일웹  20190619.0   3.0
#
# [6423 rows x 10 columns]

# %% [markdown]
# #### 배송번호를 분리해서 사용했을 때

# %%
df_shop['배송번호_date'] = df_shop['배송번호'].str.slice(2, 10)
df_shop['배송번호_date'] = df_shop['배송번호_date'].astype(int)
condition_orderdate = '배송번호_date >= 20181230'
condition_mobile = '주문경로=="모바일웹"'
condition_over = '50000 <= 상품구매금액'
conditions = f"{condition_over} and {condition_orderdate} and {condition_mobile}"
df_shop.query(conditions).sort_values(by='배송번호_date')
# Out:
#                  결제수단                   배송번호               배송시작일  \
# 3               무통장입금  D-20181231-0000087-00 2019-01-03 09:30:00
# 4               무통장입금  D-20181231-0000108-00 2019-01-07 08:56:00
# 5               무통장입금  D-20181231-0000108-01 2019-01-07 08:56:00
# 21          적립금,무통장입금  D-20181231-0000512-00 2019-01-03 09:30:00
# 25              무통장입금  D-20181231-0000727-00 2019-01-03 18:19:00
# ...               ...                    ...                 ...
# 17544           무통장입금  D-20190602-0000017-02 2019-06-10 08:45:00
# 17546           무통장입금  D-20190602-0000017-04 2019-06-10 08:45:00
# 17545    카카오페이(카카오머니)  D-20190604-0000018-00 2019-06-10 08:45:00
# 17547  페이나우(실시간 계좌이체)  D-20190619-0000037-00 2019-06-20 17:32:00
# 17548  페이나우(실시간 계좌이체)  D-20190619-0000053-00 2019-06-20 17:32:00
#
#                     배송완료일    상품구매금액    상품번호   수량  주문경로         주문일  배송기간  \
# 3     2019-01-07 05:32:00   81600.0  1085.0  1.0  모바일웹  20181231.0   3.0
# 4     2019-01-11 05:32:00   94710.0  1106.0  1.0  모바일웹  20181231.0   3.0
# 5     2019-01-11 05:32:00   75240.0  1374.0  1.0  모바일웹  20181231.0   3.0
# 21    2019-01-07 05:32:00  115170.0    68.0  1.0  모바일웹  20181231.0   3.0
# 25    2019-01-07 05:32:00  190420.0  1322.0  2.0  모바일웹  20181231.0   3.0
# ...                   ...       ...     ...  ...   ...         ...   ...
# 17544 2019-06-14 05:32:00   60900.0  1374.0  1.0  모바일웹  20190602.0   3.0
# 17546 2019-06-14 05:32:00   90000.0  1625.0  2.0  모바일웹  20190602.0   3.0
# 17545 2019-06-14 05:32:00   61900.0   608.0  1.0  모바일웹  20190604.0   3.0
# 17547 2019-06-24 05:32:00   52400.0  1373.0  1.0  모바일웹  20190619.0   3.0
# 17548 2019-06-24 05:32:00   60900.0  1374.0  1.0  모바일웹  20190619.0   3.0
#
#        배송번호_date
# 3       20181231
# 4       20181231
# 5       20181231
# 21      20181231
# 25      20181231
# ...          ...
# 17544   20190602
# 17546   20190602
# 17545   20190604
# 17547   20190619
# 17548   20190619
#
# [6423 rows x 11 columns]

# %%
df_shop['배송번호_date'].astype(int)
# Out:
# 0        20181227
# 1        20181229
# 2        20181230
# 3        20181231
# 4        20181231
#            ...
# 17879    20180115
# 17880    20180115
# 17881    20180115
# 17882    20180115
# 17883    20180115
# Name: 배송번호_date, Length: 17884, dtype: int64
