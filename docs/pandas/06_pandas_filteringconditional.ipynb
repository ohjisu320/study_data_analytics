# %% [markdown]
# <a href="https://colab.research.google.com/github/ohjisu320/study_data_analytics/blob/main/docs/pandas/06_pandas_filteringconditional.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
# DataFrame 생성
data = {
    '이름': ['홍길동', '김철수', '이영희', '박지성', '김연아'],
    '나이': [25, 32, 19, 28, 31],
    '성별': ['남', '남', '여', '남', '여']
}
df_temp = pd.DataFrame(data)

# %% [markdown]
# ## conditional filtering

# %% [markdown]
# ### boolean indexing

# %%
df_temp['나이'] >= 30
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4     True
# Name: 나이, dtype: bool

# %%
# df_temp[df_temp['나이'] >= 30]
df_temp.loc[df_temp['나이'] >= 30]
# Out:
#     이름  나이 성별
# 1  김철수  32  남
# 4  김연아  31  여

# %%
condition_males = df_temp['성별'] == '남'
condition_under_30 = df_temp['나이'] < 30
conditions = condition_males & condition_under_30
df_temp.loc[conditions]
# Out:
#     이름  나이 성별
# 0  홍길동  25  남
# 3  박지성  28  남

# %%
df_temp.set_index("이름", inplace=True) # 이름 컬럼을 index로 지정
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-47-9ab4e5fbd67d> in <cell line: 1>()
# ----> 1 df_temp.set_index("이름", inplace=True) # 이름 컬럼을 index로 지정
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    6010
#    6011         if missing:
# -> 6012             raise KeyError(f"None of {missing} are in the columns")
#    6013
#    6014         if inplace:
#
# KeyError: "None of ['이름'] are in the columns"

# %%
condition_in = ['홍길동', '이영희']
df_temp.loc[condition_in]
# Out:
#      나이 성별
# 이름
# 홍길동  25  남
# 이영희  19  여

# %% [markdown]
# ### query

# %%
df_temp.query('나이 >= 30')
# Out:
#     이름  나이 성별
# 1  김철수  32  남
# 4  김연아  31  여

# %%
conditon_males = '성별 == "남"'
df_temp.query(conditon_males)
# Out:
#     이름  나이 성별
# 0  홍길동  25  남
# 1  김철수  32  남
# 3  박지성  28  남

# %%
df_temp[['이름', '성별']].query(conditon_males)
# df_temp[['이름', '성별']].query(conditon_males).columns
# Out:
#     이름 성별
# 0  홍길동  남
# 1  김철수  남
# 3  박지성  남

# %%
condition_under_30 = '나이 < 30 '
# conditions ='{} and {}'.format(conditon_males,condition_under_30)
conditions =f'{conditon_males} and {condition_under_30}'
df_temp.query(conditions)
# Out:
#     이름  나이 성별
# 0  홍길동  25  남
# 3  박지성  28  남

# %%
condition_in = '이름 in ["홍길동", "이영희"]'
df_temp.query(condition_in)
# Out:
#     이름  나이 성별
# 0  홍길동  25  남
# 2  이영희  19  여
